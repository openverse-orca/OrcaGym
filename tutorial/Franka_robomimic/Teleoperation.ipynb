# %% [markdown]
# # Control the Franka Panda Robot via Teleoperation.
#
# * **Environment**
#
# | Package       | Version   |
# |---------------|-----------|
# | gymnasium     | No Need   |
# | numpy         | 1.24.0    |
# | grpcio        | 1.64.1    |
# | pygame        | 2.6.0     |
# | Level Name    | Franka_Joystick |
#
# * Control the gripper's pose using the xbox joystick
# * Guide the robot's movement through an **OSC** controller
# * Implement recording and replay functionality to store and replay control inputs, used for demonstration and imitation learning training

# %% [markdown]
# ## Testing Xbox Controller Input
#
# * Run a test program to confirm that the controller is receiving input signals
# * Press the corresponding buttons to print information

# %%
import os
import sys
import time

current_file_path = os.path.abspath('')
project_root = os.path.dirname(current_file_path)

if project_root not in sys.path:
    sys.path.append(project_root)

from orca_gym.devices.xbox_joystick import XboxJoystickManager

def test_xbox_controller():
    try:
        joystick_manager = XboxJoystickManager()
        joystick_names = joystick_manager.get_joystick_names()
        joysticks = [joystick_manager.get_joystick(name) for name in joystick_names]
        while True:
            joystick_manager.update()      
            for i, joystick in enumerate(joysticks):
                state = joystick.get_state()
                print("Controller:", joystick_names[i])
                print("Buttons:", state["buttons"])
                print("Axes:", state["axes"])
                print("Hats:", state["hats"])
            time.sleep(1)
    except KeyboardInterrupt:
        joystick_manager.close()
        print("Controller closed")

if __name__ == '__main__':
    test_xbox_controller()

# %% [markdown]
# ## Testing Keyboard Input
#
# To accommodate different operating systems, the Pygame library is used to implement keyboard input detection. When running the program, a small window will appear, and you need to focus on this window for key inputs to be captured. Press the corresponding keys (A/W/S/D/Up/Down, etc.) and observe the printed output.

# %%
import os
import sys
import time

current_file_path = os.path.abspath('')
project_root = os.path.dirname(current_file_path)

if project_root not in sys.path:
    sys.path.append(project_root)

from orca_gym.devices.keyboard import KeyboardInput

def test_keyboard_controller():
    try:
        controller = KeyboardInput()
        while True:
            controller.update()            
            state = controller.get_state()
            print("Keys:", state)
            if state["Esc"]:
                raise KeyboardInterrupt("Esc key pressed")
                break
            time.sleep(1)
    except KeyboardInterrupt:
        controller.close()
        print("Controller closed")

if __name__ == '__main__':
    test_keyboard_controller()

# %% [markdown]
# In the example above, a keyboard class instance corresponds to a control program. If you run multiple environments in parallel, each with a robot that can be controlled, you will need to switch between different control instances (small windows).
#
# If you want to use a single keyboard instance to control multiple environments simultaneously, such as operating a formation of robots using keypresses, you can use the `KeyboardServer` and `KeyboardClient` objects.
#
# Since Jupyter notebooks are not convenient for demonstrating multi-process examples, this example is located in `examples/teleoperation/keyboard_input`.
#
# * Run `run_server.py` to start a keyboard control service that listens for user input. A small window will pop up.
# * Run `run_clients.py` to start two clients that listen to the server's broadcasts. At this point, focus on the small window that popped up earlier, and when you press a key, both clients will print the received keypress input.

# %% [markdown]
# ## Control the Franka Panda Robot Arm
#
# Apply offsets to the mocap point inputs based on the controller state
#
# * **Using Xbox Controller:**
#     * Left joystick controls parallel movement of the gripper
#     * Right joystick controls pitch and yaw of the gripper
#     * LT/RT controls forward and backward extension of the gripper
#     * LB/RB controls rotation of the gripper
#     * A/B controls opening and closing of the gripper
#
#  In this example, The player's task is to operate the robot arm to pick up the block and lift the block vertically up to 0.1 meters. The operations will be recorded and stored in a .hdh5 file (refer to the implementation of the `run_example` function). In the next step, we will replay these operations.
#
#  The gameplay is divided into multiple episodes. At the end of each episode, the game will pause and ask the player whether to save the record for this episode. Enter "Y" and press Enter to keep the record, or enter "N" and press Enter to discard it. After exiting the program, you can view the HDF5 file (it's recommended to use the H5Web plugin in VS Code) to see the data tracking for each episode.

# %%
import os
import sys
import time

current_file_path = os.path.abspath('')
project_root = os.path.dirname(current_file_path)

if project_root not in sys.path:
    sys.path.append(project_root)


import gymnasium as gym
from gymnasium.envs.registration import register
from datetime import datetime
from envs.orca_gym_env import RewardType
from envs.robomimic.robomimic_env import ControlType
from envs.robomimic.dataset_util import DatasetWriter

from envs.openloong.camera_wrapper import *

import numpy as np
import asyncio
import nest_asyncio
nest_asyncio.apply()

TIME_STEP = 0.01
MAX_EPISODE_STEPS = 10 / TIME_STEP # 10 seconds in normal speed.

def register_env(env_name, env_index, **kwargs) -> str:
    orcagym_addr = kwargs['orcagym_addr']
    orcagym_addr_str = orcagym_addr.replace(":", "-")
    env_id = env_name + "-OrcaGym-" + orcagym_addr_str + f"-{env_index:03d}"
    gym.register(
        id=env_id,
        entry_point="envs.franka_control.franka_teleoperation_env:FrankaTeleoperationEnv",
        kwargs=kwargs,
        max_episode_steps= MAX_EPISODE_STEPS,  # 10 seconds
        reward_threshold=0.0,
    )
    return env_id

def run_episode(env, dataset_writer):
    obs, info = env.reset(seed=42)
    obs_list = {obs_key: list([]) for obs_key, obs_data in obs.items()}
    reward_list = []
    done_list = []
    info_list = []    
    ts_list = []
    terminated_times = 0
    while True:
        start_time = datetime.now()

        ts_list.append(int(start_time.timestamp() * 1000))

        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)
        
        for obs_key, obs_data in obs.items():
            obs_list[obs_key].append(obs_data)
            
        reward_list.append(reward)
        done_list.append(0 if not terminated else 1)
        info_list.append(info)
        terminated_times = terminated_times + 1 if terminated else 0

        if terminated_times >= 5 or truncated:
            return obs_list, reward_list, done_list, info_list, ts_list

        elapsed_time = datetime.now() - start_time
        if elapsed_time.total_seconds() < TIME_STEP:
            time.sleep(TIME_STEP - elapsed_time.total_seconds())
        else:
            print("Over time! elapsed_time (ms): ", elapsed_time.total_seconds() * 1000)

def user_comfirm_save_record(task_result):
    while True:
        user_input = input(f"Task is {task_result}! Do you want to save the record? (y/n): ")
        if user_input == 'y':
            return True
        elif user_input == 'n':
            return False
        else:
            print("Invalid input! Please input 'y' or 'n'.")

def do_teleoperation(env, dataset_writer):
    while True:
        save_camera = False
        camera_name_list = ["main_camera"]
        camera_list = []
        if save_camera:
            for camera_name in camera_name_list:
                camera = CameraCacher(camera_name, 7070)
                camera.start()
                camera_list.append(camera)
            for camera in camera_list:
                while not camera.is_first_frame_received():
                    time.sleep(0.001)

        obs_list, reward_list, done_list, info_list, ts_list = run_episode(env, dataset_writer)
        task_result = "Success" if done_list[-1] == 1 else "Failed"
        save_record = user_comfirm_save_record(task_result)
        if save_record:
            if save_camera:
                for camera in camera_list:
                    camera.stop()

            dataset_writer.add_demo({
                'states': np.array([np.concatenate([info["state"]["qpos"], info["state"]["qvel"]]) for info in info_list]),
                'actions': np.array([info["action"] for info in info_list]),
                'rewards': np.array(reward_list),
                'dones': np.array(done_list),
                'obs': obs_list,
                }, save_camera, camera_name_list, ts_list)


async def run_example():
    try:
        orcagym_addr = "localhost:50051"
        print("simulation running... , orcagym_addr: ", orcagym_addr)

        env_name = "Franka-Teleoperation-v0"
        env_index = 0
        kwargs = {'frame_skip': 1,   
                    'reward_type': RewardType.DENSE,
                    'orcagym_addr': orcagym_addr, 
                    'agent_names': ['Panda'], 
                    'time_step': TIME_STEP,
                    'control_type': ControlType.TELEOPERATION,
                    'control_freq': 20}        
        env_id = register_env(env_name, env_index, **kwargs)
        print("Registered environment: ", env_id)

        env = gym.make(env_id)        
        print("Starting simulation...")

        # formatted_now = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        # dataset_writer = DatasetWriter(file_path=f"teleoperation_dataset_{formatted_now}.hdf5",
        #                                env_name=env_id,
        #                                env_version=env.get_env_version(),
        #                                env_kwargs=kwargs)

        dataset_writer = DatasetWriter(file_path=f"teleoperation_dataset.hdf5",
                                       env_name=env_id,
                                       env_version=env.get_env_version(),
                                       env_kwargs=kwargs)

        do_teleoperation(env, dataset_writer)
        dataset_writer.finalize()
    except KeyboardInterrupt:
        print("Simulation stopped")        
        dataset_writer.finalize()
        env.close()
    

if __name__ == "__main__":
    """
    An example of an OSC (Operational Space Control) motion algorithm controlling a Franka robotic arm.
    Level: Franka_Joystick
    Differences from the mocap version:
    1. Motor control uses torque output (moto) instead of setting joint angles.
    2. Torque calculation is based on the OSC algorithm.
    3. The mocap point can move freely and is not welded to the site; the pulling method is not used.
    """

    asyncio.run(run_example())

# %% [markdown]
# ## Replay the Previous Operations

# %%
import os
import sys
import time

current_file_path = os.path.abspath('')
project_root = os.path.dirname(current_file_path)

if project_root not in sys.path:
    sys.path.append(project_root)

import gymnasium as gym
from gymnasium.envs.registration import register
from datetime import datetime
from envs.robomimic.dataset_util import DatasetReader
from envs.orca_gym_env import RewardType
from envs.robomimic.robomimic_env import ControlType
import asyncio
import nest_asyncio
nest_asyncio.apply()

TIME_STEP = 0.01
MAX_EPISODE_STEPS = 10 / TIME_STEP  # 10 seconds in normal speed.


def register_env(env_name, env_index, **kwargs) -> str:
    orcagym_addr = kwargs['orcagym_addr']
    orcagym_addr_str = orcagym_addr.replace(":", "-")
    env_id = env_name + "-OrcaGym-" + orcagym_addr_str + f"-{env_index:03d}"
    gym.register(
        id=env_id,
        entry_point="envs.franka_control.franka_teleoperation_env:FrankaTeleoperationEnv",
        kwargs=kwargs,
        max_episode_steps=MAX_EPISODE_STEPS,  # 10 seconds
        reward_threshold=0.0,
    )
    return env_id


def replay_demo(env, demo_data):
    env.reset(seed=42)
    """
    回放数据集中的演示。

    参数：
    - env: 环境对象。
    - demo_data: 包含演示数据的字典。
    """
    obs = demo_data["obs"]
    actions = demo_data["actions"]
    rewards = demo_data["rewards"]
    dones = demo_data["dones"]

    print("Starting replay...")
    for i in range(len(actions)):
        print(f"Step {i + 1}/{len(actions)}")
        action = actions[i]
        env.step(action)  # 将动作应用到环境中

        time.sleep(TIME_STEP)  # 模拟时间步长

        if dones[i]:
            print("Episode terminated.")
            break


def user_choose_demo(demo_names):
    """
    让用户选择一个演示。

    参数：
    - demo_names: 可供选择的演示名称列表。

    返回：
    - chosen_demo: 用户选择的演示名称。
    """
    print("Available Demos:")
    for i, name in enumerate(demo_names):
        print(f"{i + 1}. {name}")

    while True:
        try:
            choice = int(input("Select a demo to replay (1-N): ")) - 1
            if 0 <= choice < len(demo_names):
                return demo_names[choice]
            else:
                print("Invalid choice. Please try again.")
        except ValueError:
            print("Invalid input. Please input a number.")


async def run_example():
    try:
        orcagym_addr = "localhost:50051"
        print("Simulation running..., orcagym_addr: ", orcagym_addr)

        env_name = "Franka-Teleoperation-v0"
        env_index = 0
        kwargs = {'frame_skip': 1,
                  'reward_type': RewardType.SPARSE,
                  'orcagym_addr': orcagym_addr,
                  'agent_names': ['Panda'],
                  'time_step': TIME_STEP,
                  'control_type': ControlType.DIRECT,
                  'control_freq': 20}
        env_id = register_env(env_name, env_index, **kwargs)
        print("Registered environment: ", env_id)

        env = gym.make(env_id)
        print("Starting simulation...")

        # 从 HDF5 数据集中加载数据
        # dataset_path = input("Enter the path to the dataset file (e.g., dataset.hdf5): ").strip()
        dataset_path = "teleoperation_dataset.hdf5"
        dataset_reader = DatasetReader(file_path=dataset_path)

        demo_names = dataset_reader.get_demo_names()
        # chosen_demo = user_choose_demo(demo_names)
        chosen_demo = "demo_5"

        demo_data = dataset_reader.load_demo(chosen_demo)
        print(f"Loaded demo: {chosen_demo}")
        
        # 使用演示数据回放
        replay_demo(env, demo_data)

    except KeyboardInterrupt:
        print("Simulation stopped")
        env.close()


if __name__ == "__main__":
    """
    Example of replaying dataset-based demonstrations in a simulation environment.
    Level: Franka_Joystick
    Replays actions and observations stored in a dataset for validation or analysis.
    """

    asyncio.run(run_example())
# Out:
# Simulation running..., orcagym_addr:  localhost:50051
# Registered environment:  Franka-Teleoperation-v0-OrcaGym-localhost-50051-000
# [robosuite WARNING] No private macro file found! (macros.py:53)
# [robosuite WARNING] It is recommended to use a private macro file (macros.py:54)
# [robosuite WARNING] To setup, run: python d:\CodeSpace\OrcaGym\orca_gym\robosuite/scripts/setup_macros.py (macros.py:55)
# Initializing simulation: Class: FrankaTeleoperationEnv
# Opt config:  timestep:0.01 iterations:100 noslip_iterations:10 mpr_iterations:50 sdf_iterations:10 gravity:[0.0, 0.0, -9.81000042]
# Model info:  nq:16 nv:15 nu:9 nbody:17 njnt:10 ngeom:25 nsite:2
# ctrl range:  [[-8.00e+01  8.00e+01]
#  [-8.00e+01  8.00e+01]
#  [-4.80e+01  4.80e+01]
#  [-4.80e+01  4.80e+01]
#  [-1.24e+01  1.24e+01]
#  [-1.24e+01  1.24e+01]
#  [-1.24e+01  1.24e+01]
#  [ 0.00e+00  4.00e-02]
#  [ 0.00e+00  4.00e-02]]
# sample object position, quaternion:  [1.76998641 0.09356616 0.05      ] [0.21102731 0.         0.         0.97748017]
# current_path:  d:\CodeSpace\OrcaGym\orca_gym\robosuite\controllers
# Starting simulation...
# Loaded demo: demo_5
# sample object position, quaternion:  [ 1.75194615 -0.11326257  0.05      ] [0.9963567  0.         0.         0.08528385]
# sample goal position:  [ 1.75194615 -0.11326257  0.15      ]
# Starting replay...
# Step 1/467
# Step 2/467
# Step 3/467
# Step 4/467
# Step 5/467
# Step 6/467
# Step 7/467
# Step 8/467
# Step 9/467
# Step 10/467
# Step 11/467
# Step 12/467
# Step 13/467
# Step 14/467
# Step 15/467
# Step 16/467
# Step 17/467
# Step 18/467
# Step 19/467
# Step 20/467
# Step 21/467
# Step 22/467
# Step 23/467
# Step 24/467
# Step 25/467
# Step 26/467
# Step 27/467
# Step 28/467
# Step 29/467
# Step 30/467
# Step 31/467
# Step 32/467
# Step 33/467
# Step 34/467
# Step 35/467
# Step 36/467
# Step 37/467
# Step 38/467
# Step 39/467
# Step 40/467
# Step 41/467
# Step 42/467
# Step 43/467
# Step 44/467
# Step 45/467
# Step 46/467
# Step 47/467
# Step 48/467
# Step 49/467
# Step 50/467
# Step 51/467
# Step 52/467
# Step 53/467
# Step 54/467
# Step 55/467
# Step 56/467
# Step 57/467
# Step 58/467
# Step 59/467
# Step 60/467
# Step 61/467
# Step 62/467
# Step 63/467
# Step 64/467
# Step 65/467
# Step 66/467
# Step 67/467
# Step 68/467
# Step 69/467
# Step 70/467
# Step 71/467
# Step 72/467
# Step 73/467
# Step 74/467
# Step 75/467
# Step 76/467
# Step 77/467
# Step 78/467
# Step 79/467
# Step 80/467
# Step 81/467
# Step 82/467
# Step 83/467
# Step 84/467
# Step 85/467
# Step 86/467
# Step 87/467
# Step 88/467
# Step 89/467
# Step 90/467
# Step 91/467
# Step 92/467
# Step 93/467
# Step 94/467
# Step 95/467
# Step 96/467
# Step 97/467
# Step 98/467
# Step 99/467
# Step 100/467
# Step 101/467
# Step 102/467
# Step 103/467
# Step 104/467
# Step 105/467
# Step 106/467
# Step 107/467
